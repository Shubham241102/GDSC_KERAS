# %% [markdown]
# # import Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
path=r"C:\Users\krshu\OneDrive\Desktop\automobileEDA.csv"
df=pd.read_csv(path)
df.head()
# Out:
#    symboling  normalized-losses         make aspiration num-of-doors  \
# 0          3                122  alfa-romero        std          two
# 1          3                122  alfa-romero        std          two
# 2          1                122  alfa-romero        std          two
# 3          2                164         audi        std         four
# 4          2                164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base    length  ...  \
# 0  convertible          rwd           front        88.6  0.811148  ...
# 1  convertible          rwd           front        88.6  0.811148  ...
# 2    hatchback          rwd           front        94.5  0.822681  ...
# 3        sedan          fwd           front        99.8  0.848630  ...
# 4        sedan          4wd           front        99.4  0.848630  ...
#
#    compression-ratio  horsepower  peak-rpm city-mpg highway-mpg    price  \
# ...

# %%
del df['make']

# %%
del df['body-style']

# %%
del df['aspiration']

# %%
del df['num-of-doors']

# %%
del df['drive-wheels']

# %%
del df['engine-type']

# %%
del df['num-of-cylinders']

# %%
del df['fuel-system']

# %%
del df['horsepower-binned']

# %%
df.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    int64
#  2   wheel-base         201 non-null    float64
#  3   length             201 non-null    float64
#  4   width              201 non-null    float64
#  5   height             201 non-null    float64
#  6   curb-weight        201 non-null    int64
#  7   engine-size        201 non-null    int64
#  8   bore               201 non-null    float64
#  9   stroke             197 non-null    float64
#  10  compression-ratio  201 non-null    float64
#  11  horsepower         201 non-null    float64
#  12  peak-rpm           201 non-null    float64
#  13  city-mpg           201 non-null    int64
#  14  highway-mpg        201 non-null    int64
#  15  price              201 non-null    float64
# ...

# %%
df.describe()
# Out:
#         symboling  normalized-losses  wheel-base      length       width  \
# count  201.000000          201.00000  201.000000  201.000000  201.000000
# mean     0.840796          122.00000   98.797015    0.837102    0.915126
# std      1.254802           31.99625    6.066366    0.059213    0.029187
# min     -2.000000           65.00000   86.600000    0.678039    0.837500
# 25%      0.000000          101.00000   94.500000    0.801538    0.890278
# 50%      1.000000          122.00000   97.000000    0.832292    0.909722
# 75%      2.000000          137.00000  102.400000    0.881788    0.925000
# max      3.000000          256.00000  120.900000    1.000000    1.000000
#
#            height  curb-weight  engine-size        bore      stroke  \
# count  201.000000   201.000000   201.000000  201.000000  197.000000
# mean    53.766667  2555.666667   126.875622    3.330692    3.256904
# std      2.447822   517.296727    41.546834    0.268072    0.319256
# ...

# %% [markdown]
# # Finding Correlation

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %%
df.head()
# Out:
#    symboling  normalized-losses  wheel-base    length     width  height  \
# 0          3                122        88.6  0.811148  0.890278    48.8
# 1          3                122        88.6  0.811148  0.890278    48.8
# 2          1                122        94.5  0.822681  0.909722    52.4
# 3          2                164        99.8  0.848630  0.919444    54.3
# 4          2                164        99.4  0.848630  0.922222    54.3
#
#    curb-weight  engine-size  bore  stroke  compression-ratio  horsepower  \
# 0         2548          130  3.47    2.68                9.0       111.0
# 1         2548          130  3.47    2.68                9.0       111.0
# 2         2823          152  2.68    3.47                9.0       154.0
# 3         2337          109  3.19    3.40               10.0       102.0
# 4         2824          136  3.19    3.40                8.0       115.0
#
#    peak-rpm  city-mpg  highway-mpg    price  city-L/100km  diesel  gas
# ...

# %%
plt.figure(figsize=(4,6))
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.scatter(x="engine-size", y="price", data=df)
plt.show()

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (201, 19)

# %%
print('Training size =' , 0.80*201)
# Out:
# Training size = 160.8

# %%
df[["engine-size", "price"]].corr()
# Out:
#              engine-size     price
# engine-size     1.000000  0.872335
# price           0.872335  1.000000

# %% [markdown]
# Highway mpg is a potential predictor variable of price

# %%
sns.regplot(x="highway-mpg", y="price", data=df)
# Out:
# <Axes: xlabel='highway-mpg', ylabel='price'>

# %%
df[['highway-mpg', 'price']].corr()
# Out:
#              highway-mpg     price
# highway-mpg     1.000000 -0.704692
# price          -0.704692  1.000000

# %% [markdown]
# correlation between 'highway-mpg' and 'price' and see it's approximately -0.704

# %%
df.corr()
# Out:
#                    symboling  normalized-losses  wheel-base    length  \
# symboling           1.000000           0.466264   -0.535987 -0.365404
# normalized-losses   0.466264           1.000000   -0.056661  0.019424
# wheel-base         -0.535987          -0.056661    1.000000  0.876024
# length             -0.365404           0.019424    0.876024  1.000000
# width              -0.242423           0.086802    0.814507  0.857170
# height             -0.550160          -0.373737    0.590742  0.492063
# curb-weight        -0.233118           0.099404    0.782097  0.880665
# engine-size        -0.110581           0.112360    0.572027  0.685025
# bore               -0.140019          -0.029862    0.493244  0.608971
# stroke             -0.008245           0.055563    0.158502  0.124139
# compression-ratio  -0.182196          -0.114713    0.250313  0.159733
# horsepower          0.075819           0.217299    0.371147  0.579821
# ...

# %% [markdown]
# for linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr= LinearRegression()

# %%
lr
# Out:
# LinearRegression()

# %%
X = df[['highway-mpg']]
Y = df['price']

# %% [markdown]
# Now , fitting part

# %%
lr.fit(X,Y)
# Out:
# LinearRegression()

# %% [markdown]
# We can output a prediction

# %%
Yhat=lr.predict(X)
Yhat[0:5]
# Out:
# array([16236.50464347, 16236.50464347, 17058.23802179, 13771.3045085 ,
#        20345.17153508])

# %%
lr.intercept_
# Out:
# 38423.3058581574

# %%
lr.coef_
# Out:
# array([-821.73337832])

# %% [markdown]
# # Multiple Linear Regression

# %% [markdown]
# now for multiple variables

# %%
a = df[['horsepower', 'curb-weight', 'engine-size', 'highway-mpg']]

# %% [markdown]
# Fitting the linear model

# %%
lr.fit(a, df['price'])
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# -15806.624626329227

# %%
lr.coef_
# Out:
# array([53.49574423,  4.70770099, 81.53026382, 36.05748882])

# %% [markdown]
# # Now Regression Plot

# %%
width = 12
height = 10
plt.figure(figsize=(width, height))
sns.regplot(x="highway-mpg", y="price", data=df)
plt.ylim(0,)
# Out:
# (0.0, 48178.162149546864)

# %% [markdown]
# # Now for complete Multiple Regression

# %% [markdown]
# First lets make a prediction

# %%
Y = lr.predict(a)

# %%
plt.figure(figsize=(6,5))


ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
sns.distplot(Y, hist=False, color="b", label="Fitted Values" , ax=ax1)


plt.title('Actual vs Fitted Values for Price')
plt.xlabel('Price (in dollars)')
plt.ylabel('Proportion of Cars')

plt.show()
plt.close()
# Out:
# C:\Users\krshu\AppData\Local\Temp\ipykernel_14000\3062354626.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax1 = sns.distplot(df['price'], hist=False, color="r", label="Actual Value")
# C:\Users\krshu\AppData\Local\Temp\ipykernel_14000\3062354626.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Measures for In-Sample Evaluation

# %% [markdown]
# Let's calculate the R^2 for linear regression

# %%
#highway_mpg_fit
lr.fit(X, Y)
# Find the R^2
print('The R-square is: ', lr.score(X, Y))
# Out:
# The R-square is:  0.6135631492602351

# %%
Y=lr.predict(X)
print('The output of the first four predicted value is: ', Y[0:4])
# Out:
# The output of the first four predicted value is:  [16236.50464347 16236.50464347 17058.23802179 13771.3045085 ]

# %% [markdown]
# Now R^2 for Multiple Linear Regression

# %%
# fit the model 
lr.fit(a, df['price'])
# Find the R^2
print('The R-square is: ', lr.score(a, df['price']))
# Out:
# The R-square is:  0.8093562806577457

# %% [markdown]
# # Prediction

# %%
new=np.arange(1, 100, 1).reshape(-1, 1)

# %%
lr.fit(X, Y)
lr
# Out:
# LinearRegression()

# %%
y=lr.predict(new)
y[0:5]
# Out:
# C:\Users\krshu\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37601.57247984, 36779.83910151, 35958.10572319, 35136.37234487,
#        34314.63896655])

# %%
plt.plot(new, y)
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# Here as the result we have 27 variables in total, and we know that more than one of those variables are potential predictors of the final car price.
